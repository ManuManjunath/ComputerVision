# %%
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

img = cv2.imread("data/00-puppy.jpg")

# Default colours (BGR)
img_default = plt.imshow(img)

# %%
# Convert to RGB
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
# Convert to HSV --> Hue, Saturation, Value
img3 = cv2.cvtColor(img2, cv2.COLOR_RGB2HSV)
plt.imshow(img3)

# %%
# Convert to HSL --> Hue, Level, Saturation
img4 = cv2.cvtColor(img2, cv2.COLOR_RGB2HLS)
plt.imshow(img4)
