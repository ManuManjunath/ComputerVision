# %% [raw]
# A histogram is a visual representation of the distribution of a continuous feature.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dark_horse = cv2.imread("data/horse.jpg")
show_horse = cv2.cvtColor(dark_horse, cv2.COLOR_BGR2RGB)

rainbow = cv2.imread("data/rainbow.jpg")
show_rainbow = cv2.cvtColor(rainbow, cv2.COLOR_BGR2RGB)

blue_bricks = cv2.imread("data/bricks.jpg")
show_bricks = cv2.cvtColor(blue_bricks, cv2.COLOR_BGR2RGB)

# cv2 functions expect BGR format. So we use original image variables.
# To visualize the image, we'll use the show_ image variables

# %%
plt.imshow(show_horse)

# %%
plt.imshow(show_rainbow)

# %%
plt.imshow(show_bricks)

# %%
hist_values = cv2.calcHist([blue_bricks], channels = [0], mask = None, histSize = [256], ranges = [0, 256])
# 0 because channel order is Blue, Green Red

print(hist_values.shape)
plt.plot(hist_values)
# Out:
# (256, 1)

# %%
hist_values = cv2.calcHist([dark_horse], channels = [0], mask = None, histSize = [256], ranges = [0, 256])
# 0 because channel order is Blue, Green Red

print(hist_values.shape)
plt.plot(hist_values)
# Out:
# (256, 1)

# %%
hist_values = cv2.calcHist([rainbow], channels = [0], mask = None, histSize = [256], ranges = [0, 256])
# 0 because channel order is Blue, Green Red

print(hist_values.shape)
plt.plot(hist_values)
# Out:
# (256, 1)

# %%
# To plot 3 colour histograms - all at once
img = blue_bricks
color = ('b', 'g', 'r')

for i, col in enumerate(color):
    histr = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(histr, color = col)
    plt.xlim([0, 256])

plt.title("Histogram for Blue Bricks")
# Out:
# Text(0.5, 1.0, 'Histogram for Blue Bricks')

# %%
# To plot 3 colour histograms - all at once
img = rainbow
color = ('b', 'g', 'r')

for i, col in enumerate(color):
    histr = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(histr, color = col)
    plt.xlim([0, 256])

plt.title("Histogram for Rainbow")
# Out:
# Text(0.5, 1.0, 'Histogram for Rainbow')

# %%
# To plot 3 colour histograms - all at once
img = dark_horse
color = ('b', 'g', 'r')

for i, col in enumerate(color):
    histr = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(histr, color = col)
    plt.xlim([0, 50])
    plt.ylim([0, 500000])

plt.title("Histogram for Horse")
# Out:
# Text(0.5, 1.0, 'Histogram for Horse')
